# %%
import pandas as pd 

weather = pd.read_csv("weather.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                              NAME  ACMH   ACSH   AWND  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0    NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0    NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0    NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0    NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0    NaN
# ...                 ...                               ...   ...    ...    ...
# 2023-12-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  19.01
# 2023-12-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  13.65
# 2023-12-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  13.42
# 2023-12-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  11.63
# 2023-12-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN    NaN
#
#             FMTM  PGTM  PRCP  SNOW  SNWD  ...  WT13  WT14  WT15  WT16  WT17  \
# DATE                                      ...
# 1970-01-01   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   NaN   NaN  0.02   0.0   0.0  ...   NaN   NaN   NaN   1.0   NaN
# 1970-01-04   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-05   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...
# 2023-12-11   NaN   NaN  0.59   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2023-12-12   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2023-12-13   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2023-12-14   NaN   4.0  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2023-12-15   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
#
#             WT18  WT19  WT21  WT22  WV01
# DATE
# 1970-01-01   NaN   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   1.0   NaN   NaN   NaN   NaN
# 1970-01-04   1.0   NaN   NaN   NaN   NaN
# 1970-01-05   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...
# 2023-12-11   NaN   NaN   NaN   NaN   NaN
# 2023-12-12   NaN   NaN   NaN   NaN   NaN
# 2023-12-13   NaN   NaN   NaN   NaN   NaN
# 2023-12-14   NaN   NaN   NaN   NaN   NaN
# 2023-12-15   NaN   NaN   NaN   NaN   NaN
#
# [19707 rows x 45 columns]

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0]

# %%
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.512102
# ACSH       0.512052
# AWND       0.259603
# FMTM       0.486274
# PGTM       0.377429
# PRCP       0.000000
# SNOW       0.000000
# SNWD       0.000000
# TAVG       0.665906
# TMAX       0.000000
# TMIN       0.000000
# TSUN       0.998427
# WDF1       0.512305
# WDF2       0.488050
# WDF5       0.492262
# WDFG       0.740143
# WDFM       0.999949
# WESD       0.691937
# WSF1       0.512153
# WSF2       0.488050
# WSF5       0.492312
# WSFG       0.621302
# WSFM       0.999949
# WT01       0.630030
# WT02       0.934947
# WT03       0.932917
# WT04       0.982595
# WT05       0.981529
# WT06       0.990815
# WT07       0.994520
# WT08       0.799767
# WT09       0.992896
# WT11       0.999290
# WT13       0.889126
# WT14       0.954991
# WT15       0.997869
# WT16       0.666261
# WT17       0.996955
# WT18       0.940782
# WT19       0.999949
# WT21       0.999746
# WT22       0.997514
# WV01       0.999949
# dtype: float64

# %%
valid_columns = weather.columns[null_pct < .05]

# %%
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
weather = weather[valid_columns].copy()

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-12-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.59   0.0   0.0
# 2023-12-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin
# DATE
# 1970-01-01    28    22
# 1970-01-02    31    22
# 1970-01-03    38    25
# 1970-01-04    31    23
# 1970-01-05    35    21
# ...          ...   ...
# 2023-12-11    53    36
# 2023-12-12    43    33
# 2023-12-13    46    36
# 2023-12-14    47    31
# 2023-12-15    56    34
#
# [19707 rows x 7 columns]

# %%
weather = weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax         int64
# tmin         int64
# dtype: object

# %%
weather.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2023-12-06', '2023-12-07', '2023-12-08', '2023-12-09', '2023-12-10',
#        '2023-12-11', '2023-12-12', '2023-12-13', '2023-12-14', '2023-12-15'],
#       dtype='object', name='DATE', length=19707)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2023-12-06', '2023-12-07', '2023-12-08', '2023-12-09',
#                '2023-12-10', '2023-12-11', '2023-12-12', '2023-12-13',
#                '2023-12-14', '2023-12-15'],
#               dtype='datetime64[ns]', name='DATE', length=19707, freq=None)

# %%
weather.index.year
# Out:
# Index([1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970,
#        ...
#        2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023],
#       dtype='int32', name='DATE', length=19707)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# DATE
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    349
# Name: count, dtype: int64

# %%
weather["snwd"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather["prcp"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-12-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.59   0.0   0.0
# 2023-12-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin
# DATE
# 1970-01-01    28    22
# 1970-01-02    31    22
# 1970-01-03    38    25
# 1970-01-04    31    23
# 1970-01-05    35    21
# ...          ...   ...
# 2023-12-11    53    36
# 2023-12-12    43    33
# 2023-12-13    46    36
# 2023-12-14    47    31
# 2023-12-15    56    34
#
# [19707 rows x 7 columns]

# %%
weather["target"] = weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-12-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.59   0.0   0.0
# 2023-12-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1970-01-01    28    22    31.0
# 1970-01-02    31    22    38.0
# 1970-01-03    38    25    31.0
# 1970-01-04    31    23    35.0
# 1970-01-05    35    21    36.0
# ...          ...   ...     ...
# 2023-12-11    53    36    43.0
# 2023-12-12    43    33    46.0
# 2023-12-13    46    36    47.0
# 2023-12-14    47    31    56.0
# 2023-12-15    56    34     NaN
#
# [19707 rows x 8 columns]

# %%
weather.ffill()
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-12-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.59   0.0   0.0
# 2023-12-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1970-01-01    28    22    31.0
# 1970-01-02    31    22    38.0
# 1970-01-03    38    25    31.0
# 1970-01-04    31    23    35.0
# 1970-01-05    35    21    36.0
# ...          ...   ...     ...
# 2023-12-11    53    36    43.0
# 2023-12-12    43    33    46.0
# 2023-12-13    46    36    47.0
# 2023-12-14    47    31    56.0
# 2023-12-15    56    34    56.0
#
# [19707 rows x 8 columns]

# %%
from sklearn.linear_model import Ridge

rr =  Ridge(alpha=.1)

# %%
predictors = weather.columns[~weather.columns.isin(["target","name","station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin'], dtype='object')

# %%
def backtest(weather, model, predictors, start = 3650, step=90): 
    all_predictions = []
    
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"],preds], axis=1)
        
        combined.columns = ["actual", "prediction"]
        
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(weather, rr, predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.229324   7.229324
# 1979-12-31    42.0   43.673798   1.673798
# 1980-01-01    41.0   41.579150   0.579150
# 1980-01-02    36.0   43.961887   7.961887
# 1980-01-03    30.0   40.204726  10.204726
# ...            ...         ...        ...
# 2023-12-11    43.0   51.370988   8.370988
# 2023-12-12    46.0   46.043706   0.043706
# 2023-12-13    47.0   48.936641   1.936641
# 2023-12-14    56.0   46.809563   9.190437
# 2023-12-15     NaN   52.396978        NaN
#
# [16057 rows x 3 columns]

# %%
predictors
# Out:
# Index(['station', 'prcp', 'snow', 'snwd', 'tmax', 'tmin'], dtype='object')

# %%
weather.ffill()
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-12-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.59   0.0   0.0
# 2023-12-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1970-01-01    28    22    31.0
# 1970-01-02    31    22    38.0
# 1970-01-03    38    25    31.0
# 1970-01-04    31    23    35.0
# 1970-01-05    35    21    36.0
# ...          ...   ...     ...
# 2023-12-11    53    36    43.0
# 2023-12-12    43    33    46.0
# 2023-12-13    46    36    47.0
# 2023-12-14    47    31    56.0
# 2023-12-15    56    34    56.0
#
# [19707 rows x 8 columns]

# %%
weather["station"]
# Out:
# DATE
# 1970-01-01    USW00094789
# 1970-01-02    USW00094789
# 1970-01-03    USW00094789
# 1970-01-04    USW00094789
# 1970-01-05    USW00094789
#                  ...
# 2023-12-11    USW00094789
# 2023-12-12    USW00094789
# 2023-12-13    USW00094789
# 2023-12-14    USW00094789
# 2023-12-15    USW00094789
# Name: station, Length: 19707, dtype: object

# %%
weather["station"] = [float(str(i).replace(",", "")) for i in weather["station"]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 weather["station"] = [float(str(i).replace(",", "")) for i in weather["station"]]
#
# Cell In[66], line 1, in <listcomp>(.0)
# ----> 1 weather["station"] = [float(str(i).replace(",", "")) for i in weather["station"]]
#
# ValueError: could not convert string to float: 'USW00094789'

# %%
weather.drop("station",axis="columns")
# Out:
#                                         name  prcp  snow  snwd  tmax  tmin  \
# DATE
# 1970-01-01  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0    28    22
# 1970-01-02  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0    31    22
# 1970-01-03  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0    38    25
# 1970-01-04  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0    31    23
# 1970-01-05  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0    35    21
# ...                                      ...   ...   ...   ...   ...   ...
# 2023-12-11  JFK INTERNATIONAL AIRPORT, NY US  0.59   0.0   0.0    53    36
# 2023-12-12  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0    43    33
# 2023-12-13  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0    46    36
# 2023-12-14  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0    47    31
# 2023-12-15  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0    56    34
#
#             target
# DATE
# 1970-01-01    31.0
# 1970-01-02    38.0
# 1970-01-03    31.0
# 1970-01-04    35.0
# 1970-01-05    36.0
# ...            ...
# 2023-12-11    43.0
# 2023-12-12    46.0
# 2023-12-13    47.0
# 2023-12-14    56.0
# 2023-12-15     NaN
#
# [19707 rows x 7 columns]

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 3
#       1 from sklearn.metrics import mean_absolute_error
# ----> 3 mean_absolute_error(predictions["actual"], predictions["prediction"])
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:204, in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     140 @validate_params(
#     141     {
#     142         "y_true": ["array-like"],
#    (...)
#     150     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average"
#     151 ):
#     152     """Mean absolute error regression loss.
#     153
#     154     Read more in the :ref:`User Guide <mean_absolute_error>`.
#    (...)
#     202     0.85...
#     203     """
# --> 204     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     205         y_true, y_pred, multioutput
#     206     )
#     207     check_consistent_length(y_true, y_pred, sample_weight)
#     208     output_errors = np.average(np.abs(y_pred - y_true), weights=sample_weight, axis=0)
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:100, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      66 """Check that y_true and y_pred belong to the same regression task.
#      67
#      68 Parameters
#    (...)
#      97     correct keyword.
#      98 """
#      99 check_consistent_length(y_true, y_pred)
# --> 100 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     101 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     103 if y_true.ndim == 1:
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:959, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     953         raise ValueError(
#     954             "Found array with dim %d. %s expected <= 2."
#     955             % (array.ndim, estimator_name)
#     956         )
#     958     if force_all_finite:
# --> 959         _assert_all_finite(
#     960             array,
#     961             input_name=input_name,
#     962             estimator_name=estimator_name,
#     963             allow_nan=force_all_finite == "allow-nan",
#     964         )
#     966 if ensure_min_samples > 0:
#     967     n_samples = _num_samples(array)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:124, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     121 if first_pass_isfinite:
#     122     return
# --> 124 _assert_all_finite_element_wise(
#     125     X,
#     126     xp=xp,
#     127     allow_nan=allow_nan,
#     128     msg_dtype=msg_dtype,
#     129     estimator_name=estimator_name,
#     130     input_name=input_name,
#     131 )
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:173, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     156 if estimator_name and input_name == "X" and has_nan_error:
#     157     # Improve the error message on how to handle missing values in
#     158     # scikit-learn.
#     159     msg_err += (
#     160         f"\n{estimator_name} does not accept missing values"
#     161         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     171         "#estimators-that-handle-nan-values"
#     172     )
# --> 173 raise ValueError(msg_err)
#
# ValueError: Input contains NaN.

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.229324   7.229324
# 1979-12-31    42.0   43.673798   1.673798
# 1980-01-01    41.0   41.579150   0.579150
# 1980-01-02    36.0   43.961887   7.961887
# 1980-01-03    30.0   40.204726  10.204726
# ...            ...         ...        ...
# 2023-12-11    43.0   51.370988   8.370988
# 2023-12-12    46.0   46.043706   0.043706
# 2023-12-13    47.0   48.936641   1.936641
# 2023-12-14    56.0   46.809563   9.190437
# 2023-12-15     NaN   52.396978        NaN
#
# [16057 rows x 3 columns]

# %%
predictions.ffill()
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.229324   7.229324
# 1979-12-31    42.0   43.673798   1.673798
# 1980-01-01    41.0   41.579150   0.579150
# 1980-01-02    36.0   43.961887   7.961887
# 1980-01-03    30.0   40.204726  10.204726
# ...            ...         ...        ...
# 2023-12-11    43.0   51.370988   8.370988
# 2023-12-12    46.0   46.043706   0.043706
# 2023-12-13    47.0   48.936641   1.936641
# 2023-12-14    56.0   46.809563   9.190437
# 2023-12-15    56.0   52.396978   9.190437
#
# [16057 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 3
#       1 from sklearn.metrics import mean_absolute_error
# ----> 3 mean_absolute_error(predictions["actual"], predictions["prediction"])
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:204, in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     140 @validate_params(
#     141     {
#     142         "y_true": ["array-like"],
#    (...)
#     150     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average"
#     151 ):
#     152     """Mean absolute error regression loss.
#     153
#     154     Read more in the :ref:`User Guide <mean_absolute_error>`.
#    (...)
#     202     0.85...
#     203     """
# --> 204     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     205         y_true, y_pred, multioutput
#     206     )
#     207     check_consistent_length(y_true, y_pred, sample_weight)
#     208     output_errors = np.average(np.abs(y_pred - y_true), weights=sample_weight, axis=0)
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:100, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      66 """Check that y_true and y_pred belong to the same regression task.
#      67
#      68 Parameters
#    (...)
#      97     correct keyword.
#      98 """
#      99 check_consistent_length(y_true, y_pred)
# --> 100 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     101 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     103 if y_true.ndim == 1:
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:959, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     953         raise ValueError(
#     954             "Found array with dim %d. %s expected <= 2."
#     955             % (array.ndim, estimator_name)
#     956         )
#     958     if force_all_finite:
# --> 959         _assert_all_finite(
#     960             array,
#     961             input_name=input_name,
#     962             estimator_name=estimator_name,
#     963             allow_nan=force_all_finite == "allow-nan",
#     964         )
#     966 if ensure_min_samples > 0:
#     967     n_samples = _num_samples(array)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:124, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     121 if first_pass_isfinite:
#     122     return
# --> 124 _assert_all_finite_element_wise(
#     125     X,
#     126     xp=xp,
#     127     allow_nan=allow_nan,
#     128     msg_dtype=msg_dtype,
#     129     estimator_name=estimator_name,
#     130     input_name=input_name,
#     131 )
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:173, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     156 if estimator_name and input_name == "X" and has_nan_error:
#     157     # Improve the error message on how to handle missing values in
#     158     # scikit-learn.
#     159     msg_err += (
#     160         f"\n{estimator_name} does not accept missing values"
#     161         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     171         "#estimators-that-handle-nan-values"
#     172     )
# --> 173 raise ValueError(msg_err)
#
# ValueError: Input contains NaN.

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.229324   7.229324
# 1979-12-31    42.0   43.673798   1.673798
# 1980-01-01    41.0   41.579150   0.579150
# 1980-01-02    36.0   43.961887   7.961887
# 1980-01-03    30.0   40.204726  10.204726
# ...            ...         ...        ...
# 2023-12-11    43.0   51.370988   8.370988
# 2023-12-12    46.0   46.043706   0.043706
# 2023-12-13    47.0   48.936641   1.936641
# 2023-12-14    56.0   46.809563   9.190437
# 2023-12-15     NaN   52.396978        NaN
#
# [16057 rows x 3 columns]

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.229324   7.229324
# 1979-12-31    42.0   43.673798   1.673798
# 1980-01-01    41.0   41.579150   0.579150
# 1980-01-02    36.0   43.961887   7.961887
# 1980-01-03    30.0   40.204726  10.204726
# ...            ...         ...        ...
# 2023-12-11    43.0   51.370988   8.370988
# 2023-12-12    46.0   46.043706   0.043706
# 2023-12-13    47.0   48.936641   1.936641
# 2023-12-14    56.0   46.809563   9.190437
# 2023-12-15     NaN   52.396978        NaN
#
# [16057 rows x 3 columns]

# %%
predictions.ffill()
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.229324   7.229324
# 1979-12-31    42.0   43.673798   1.673798
# 1980-01-01    41.0   41.579150   0.579150
# 1980-01-02    36.0   43.961887   7.961887
# 1980-01-03    30.0   40.204726  10.204726
# ...            ...         ...        ...
# 2023-12-11    43.0   51.370988   8.370988
# 2023-12-12    46.0   46.043706   0.043706
# 2023-12-13    47.0   48.936641   1.936641
# 2023-12-14    56.0   46.809563   9.190437
# 2023-12-15    56.0   52.396978   9.190437
#
# [16057 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error


mean_absolute_error(predictions["actual"].ffill(), predictions["prediction"].ffill())
# Out:
# 5.1379901571072235

# %%
predictions["diff"].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of DATE
# 1979-12-30     7.229324
# 1979-12-31     1.673798
# 1980-01-01     0.579150
# 1980-01-02     7.961887
# 1980-01-03    10.204726
#                 ...
# 2023-12-11     8.370988
# 2023-12-12     0.043706
# 2023-12-13     1.936641
# 2023-12-14     9.190437
# 2023-12-15          NaN
# Name: diff, Length: 16057, dtype: float64>

# %%
predictions["diff"].ffill().mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of DATE
# 1979-12-30     7.229324
# 1979-12-31     1.673798
# 1980-01-01     0.579150
# 1980-01-02     7.961887
# 1980-01-03    10.204726
#                 ...
# 2023-12-11     8.370988
# 2023-12-12     0.043706
# 2023-12-13     1.936641
# 2023-12-14     9.190437
# 2023-12-15     9.190437
# Name: diff, Length: 16057, dtype: float64>

# %%
def pct_diff(old,new):
    return (new - old ) / old

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}__{col}"
    
    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}_pct"] = pct_diff(weather[label], weather[col])
    return weather

rolling_horizons = [3,14] 
for horizon in rolling_horizons:
    for col in ["tmax", "tmin", "prcp"]:
        weather = compute_rolling(weather, horizon,col)

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-12-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.59   0.0   0.0
# 2023-12-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target  rolling_3__tmax  rolling_3__tmax_pct  \
# DATE
# 1970-01-01    28    22    31.0              NaN                  NaN
# 1970-01-02    31    22    38.0              NaN                  NaN
# 1970-01-03    38    25    31.0        32.333333             0.175258
# 1970-01-04    31    23    35.0        33.333333            -0.070000
# 1970-01-05    35    21    36.0        34.666667             0.009615
# ...          ...   ...     ...              ...                  ...
# 2023-12-11    53    36    43.0        55.000000            -0.036364
# 2023-12-12    43    33    46.0        51.000000            -0.156863
# 2023-12-13    46    36    47.0        47.333333            -0.028169
# 2023-12-14    47    31    56.0        45.333333             0.036765
# 2023-12-15    56    34     NaN        49.666667             0.127517
#
#             rolling_3__tmin  rolling_3__tmin_pct  rolling_3__prcp  \
# DATE
# 1970-01-01              NaN                  NaN              NaN
# 1970-01-02              NaN                  NaN              NaN
# 1970-01-03        23.000000             0.086957         0.006667
# 1970-01-04        23.333333            -0.014286         0.006667
# 1970-01-05        23.000000            -0.086957         0.006667
# ...                     ...                  ...              ...
# 2023-12-11        38.000000            -0.052632         0.990000
# 2023-12-12        37.333333            -0.116071         0.990000
# 2023-12-13        35.000000             0.028571         0.196667
# 2023-12-14        33.333333            -0.070000         0.000000
# 2023-12-15        33.666667             0.009901         0.000000
#
#             rolling_3__prcp_pct  rolling_14__tmax  rolling_14__tmax_pct  \
# DATE
# 1970-01-01                  NaN               NaN                   NaN
# 1970-01-02                  NaN               NaN                   NaN
# 1970-01-03              2.00000               NaN                   NaN
# 1970-01-04             -1.00000               NaN                   NaN
# 1970-01-05             -1.00000               NaN                   NaN
# ...                         ...               ...                   ...
# 2023-12-11             -0.40404         47.571429              0.114114
# 2023-12-12             -1.00000         47.714286             -0.098802
# 2023-12-13             -1.00000         48.428571             -0.050147
# 2023-12-14                  NaN         48.285714             -0.026627
# 2023-12-15                  NaN         48.857143              0.146199
#
#             rolling_14__tmin  rolling_14__tmin_pct  rolling_14__prcp  \
# DATE
# 1970-01-01               NaN                   NaN               NaN
# 1970-01-02               NaN                   NaN               NaN
# 1970-01-03               NaN                   NaN               NaN
# 1970-01-04               NaN                   NaN               NaN
# 1970-01-05               NaN                   NaN               NaN
# ...                      ...                   ...               ...
# 2023-12-11         35.714286              0.008000          0.304286
# 2023-12-12         35.857143             -0.079681          0.304286
# 2023-12-13         36.571429             -0.015625          0.304286
# 2023-12-14         36.500000             -0.150685          0.304286
# 2023-12-15         36.428571             -0.066667          0.265000
#
#             rolling_14__prcp_pct
# DATE
# 1970-01-01                   NaN
# 1970-01-02                   NaN
# 1970-01-03                   NaN
# 1970-01-04                   NaN
# 1970-01-05                   NaN
# ...                          ...
# 2023-12-11              0.938967
# 2023-12-12             -1.000000
# 2023-12-13             -1.000000
# 2023-12-14             -1.000000
# 2023-12-15             -1.000000
#
# [19707 rows x 20 columns]

# %%
weather = weather.iloc[14:,:]

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.10   0.0   0.0
# 1970-01-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-12-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.59   0.0   0.0
# 2023-12-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target  rolling_3__tmax  rolling_3__tmax_pct  \
# DATE
# 1970-01-15    29    13    36.0        29.666667            -0.022472
# 1970-01-16    36    21    43.0        30.333333             0.186813
# 1970-01-17    43    30    42.0        36.000000             0.194444
# 1970-01-18    42    25    25.0        40.333333             0.041322
# 1970-01-19    25    16    24.0        36.666667            -0.318182
# ...          ...   ...     ...              ...                  ...
# 2023-12-11    53    36    43.0        55.000000            -0.036364
# 2023-12-12    43    33    46.0        51.000000            -0.156863
# 2023-12-13    46    36    47.0        47.333333            -0.028169
# 2023-12-14    47    31    56.0        45.333333             0.036765
# 2023-12-15    56    34     NaN        49.666667             0.127517
#
#             rolling_3__tmin  rolling_3__tmin_pct  rolling_3__prcp  \
# DATE
# 1970-01-15        18.000000            -0.277778         0.000000
# 1970-01-16        16.666667             0.260000         0.000000
# 1970-01-17        21.333333             0.406250         0.006667
# 1970-01-18        25.333333            -0.013158         0.040000
# 1970-01-19        23.666667            -0.323944         0.040000
# ...                     ...                  ...              ...
# 2023-12-11        38.000000            -0.052632         0.990000
# 2023-12-12        37.333333            -0.116071         0.990000
# 2023-12-13        35.000000             0.028571         0.196667
# 2023-12-14        33.333333            -0.070000         0.000000
# 2023-12-15        33.666667             0.009901         0.000000
#
#             rolling_3__prcp_pct  rolling_14__tmax  rolling_14__tmax_pct  \
# DATE
# 1970-01-15                  NaN         29.857143             -0.028708
# 1970-01-16                  NaN         30.214286              0.191489
# 1970-01-17              2.00000         30.571429              0.406542
# 1970-01-18              1.50000         31.357143              0.339408
# 1970-01-19             -1.00000         30.642857             -0.184149
# ...                         ...               ...                   ...
# 2023-12-11             -0.40404         47.571429              0.114114
# 2023-12-12             -1.00000         47.714286             -0.098802
# 2023-12-13             -1.00000         48.428571             -0.050147
# 2023-12-14                  NaN         48.285714             -0.026627
# 2023-12-15                  NaN         48.857143              0.146199
#
#             rolling_14__tmin  rolling_14__tmin_pct  rolling_14__prcp  \
# DATE
# 1970-01-15         18.857143             -0.310606          0.022857
# 1970-01-16         18.785714              0.117871          0.022857
# 1970-01-17         19.142857              0.567164          0.022857
# 1970-01-18         19.285714              0.296296          0.030000
# 1970-01-19         18.928571             -0.154717          0.030000
# ...                      ...                   ...               ...
# 2023-12-11         35.714286              0.008000          0.304286
# 2023-12-12         35.857143             -0.079681          0.304286
# 2023-12-13         36.571429             -0.015625          0.304286
# 2023-12-14         36.500000             -0.150685          0.304286
# 2023-12-15         36.428571             -0.066667          0.265000
#
#             rolling_14__prcp_pct
# DATE
# 1970-01-15             -1.000000
# 1970-01-16             -1.000000
# 1970-01-17             -0.125000
# 1970-01-18              2.333333
# 1970-01-19             -1.000000
# ...                          ...
# 2023-12-11              0.938967
# 2023-12-12             -1.000000
# 2023-12-13             -1.000000
# 2023-12-14             -1.000000
# 2023-12-15             -1.000000
#
# [19693 rows x 20 columns]

# %%
weather = weather.fillna(0)

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax","tmin","prcp"]:
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys=False).apply(expand_mean)
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day_of_year, group_keys=False).apply(expand_mean)

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.10   0.0   0.0
# 1970-01-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2023-12-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.59   0.0   0.0
# 2023-12-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2023-12-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target  rolling_3__tmax  rolling_3__tmax_pct  ...  \
# DATE                                                                  ...
# 1970-01-15    29    13    36.0        29.666667            -0.022472  ...
# 1970-01-16    36    21    43.0        30.333333             0.186813  ...
# 1970-01-17    43    30    42.0        36.000000             0.194444  ...
# 1970-01-18    42    25    25.0        40.333333             0.041322  ...
# 1970-01-19    25    16    24.0        36.666667            -0.318182  ...
# ...          ...   ...     ...              ...                  ...  ...
# 2023-12-11    53    36    43.0        55.000000            -0.036364  ...
# 2023-12-12    43    33    46.0        51.000000            -0.156863  ...
# 2023-12-13    46    36    47.0        47.333333            -0.028169  ...
# 2023-12-14    47    31    56.0        45.333333             0.036765  ...
# 2023-12-15    56    34     0.0        49.666667             0.127517  ...
#
#             rolling_14__tmin  rolling_14__tmin_pct  rolling_14__prcp  \
# DATE
# 1970-01-15         18.857143             -0.310606          0.022857
# 1970-01-16         18.785714              0.117871          0.022857
# 1970-01-17         19.142857              0.567164          0.022857
# 1970-01-18         19.285714              0.296296          0.030000
# 1970-01-19         18.928571             -0.154717          0.030000
# ...                      ...                   ...               ...
# 2023-12-11         35.714286              0.008000          0.304286
# 2023-12-12         35.857143             -0.079681          0.304286
# 2023-12-13         36.571429             -0.015625          0.304286
# 2023-12-14         36.500000             -0.150685          0.304286
# 2023-12-15         36.428571             -0.066667          0.265000
#
#             rolling_14__prcp_pct  month_avg_tmax  day_avg_tmax  \
# DATE
# 1970-01-15             -1.000000       29.000000     29.000000
# 1970-01-16             -1.000000       32.500000     36.000000
# 1970-01-17             -0.125000       36.000000     43.000000
# 1970-01-18              2.333333       37.500000     42.000000
# 1970-01-19             -1.000000       35.000000     25.000000
# ...                          ...             ...           ...
# 2023-12-11              0.938967       44.492140     44.907407
# 2023-12-12             -1.000000       44.491239     44.833333
# 2023-12-13             -1.000000       44.492150     45.111111
# 2023-12-14             -1.000000       44.493663     45.166667
# 2023-12-15             -1.000000       44.500603     46.388889
#
#             month_avg_tmin  day_avg_tmin  month_avg_prcp  day_avg_prcp
# DATE
# 1970-01-15       13.000000     13.000000        0.000000      0.000000
# 1970-01-16       17.000000     21.000000        0.000000      0.000000
# 1970-01-17       21.333333     30.000000        0.006667      0.020000
# 1970-01-18       22.250000     25.000000        0.030000      0.100000
# 1970-01-19       21.000000     16.000000        0.024000      0.000000
# ...                    ...           ...             ...           ...
# 2023-12-11       32.109432     33.296296        0.119027      0.106111
# 2023-12-12       32.109970     32.833333        0.118955      0.137407
# 2023-12-13       32.112319     32.833333        0.118883      0.153889
# 2023-12-14       32.111648     32.925926        0.118811      0.133704
# 2023-12-15       32.112786     33.111111        0.118739      0.122222
#
# [19693 rows x 26 columns]

# %%
predictors = weather.columns[~weather.columns.isin(["target","name","station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin', 'rolling_3__tmax',
#        'rolling_3__tmax_pct', 'rolling_3__tmin', 'rolling_3__tmin_pct',
#        'rolling_3__prcp', 'rolling_3__prcp_pct', 'rolling_14__tmax',
#        'rolling_14__tmax_pct', 'rolling_14__tmin', 'rolling_14__tmin_pct',
#        'rolling_14__prcp', 'rolling_14__prcp_pct', 'month_avg_tmax',
#        'day_avg_tmax', 'month_avg_tmin', 'day_avg_tmin', 'month_avg_prcp',
#        'day_avg_prcp'],
#       dtype='object')

# %%
predictions = backtest(weather, rr, predictors)

# %%
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 4.793605444301704

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2023-12-15     0.0   49.967628  49.967628
# 1990-03-12    85.0   54.361065  30.638935
# 2007-03-26    78.0   49.965413  28.034587
# 1998-03-26    80.0   51.966675  28.033325
# 2003-04-15    86.0   59.432179  26.567821
# ...            ...         ...        ...
# 1987-09-16    75.0   75.001185   0.001185
# 1984-08-10    83.0   82.999179   0.000821
# 2011-09-25    78.0   77.999237   0.000763
# 1999-09-28    77.0   76.999245   0.000755
# 1984-12-24    47.0   46.999514   0.000486
#
# [16043 rows x 3 columns]

# %%
predictions["diff"].round().value_counts()
# Out:
# diff
# 1.0     2216
# 2.0     2050
# 3.0     1880
# 4.0     1646
# 5.0     1420
# 6.0     1185
# 0.0     1173
# 7.0     1037
# 8.0      817
# 9.0      699
# 10.0     523
# 11.0     381
# 12.0     320
# 13.0     202
# 14.0     150
# 15.0      96
# 16.0      79
# 17.0      54
# 18.0      33
# 19.0      25
# 21.0      14
# 20.0      13
# 22.0      11
# 23.0       7
# 24.0       4
# 25.0       2
# 28.0       2
# 26.0       1
# 31.0       1
# 27.0       1
# 50.0       1
# Name: count, dtype: int64

# %%
predictions["diff"].round().value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='diff'>
